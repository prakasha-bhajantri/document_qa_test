# %%
a = [1,2,3]
b = [1,2,3]
c = a+b

# %%
c
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
len(a)
# Out:
# 3

# %%
a = [1,2,3,4,5]

for i in range(len(a)):
    print("Index-->", i, "value-->", a[i])
    
    # print(a[i])
# Out:
# Index--> 0 value--> 1
# Index--> 1 value--> 2
# Index--> 2 value--> 3
# Index--> 3 value--> 4
# Index--> 4 value--> 5

# %%
a = ["a","b","c","d"]
for i in range(len(a)):
    print(i+1)
    print("#")
    print(a[i+1])
# Out:
# 1
# #
# b
# 2
# #
# c
# 3
# #
# d
# 4
# #
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 5
#       3 print(i+1)
#       4 print("#")
# ----> 5 print(a[i+1])
#
# IndexError: list index out of range

# %%
c = {"a":6, "b":5}
if "a" in c:
    print("h")
# Out:
# h

# %%
c["a"]
# Out:
# 6

# %%
#input
words = ["apple", "banana", "apple", "orange", "banana", "apple"]

#output
a = {
  "apple": 3,
  "banana": 2,
  "orange": 1
}
count_words = {}

for w in words:
    print(w)
    if w in count_words:
        count_words[w] = count_words[w] + 1
    else:
        count_words[w] = 1
    # break


count_words
# Out:
# apple
# banana
# apple
# orange
# banana
# apple
# {'apple': 3, 'banana': 2, 'orange': 1}

# %%
count_words
# Out:
# {'apple': 3, 'banana': 2, 'orange': 1}

# %%
count_words["apple"] = count_words["apple"] +1

count_words
# Out:
# {'apple': 4, 'banana': 2, 'orange': 1}
